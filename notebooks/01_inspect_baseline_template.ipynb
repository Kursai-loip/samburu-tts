# %% [markdown]
# <a href="https://colab.research.google.com/github/Kursai-loip/samburu-tts/blob/main/notebooks/01_inspect_baseline_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Samburu TTS - Template Notebook
#
# This notebook is part of the Samburu TTS Improvement Roadmap.
#
# > Open this notebook in Colab after uploading to GitHub.
#
# Use GPU runtime (`Runtime` > `Change runtime type` > `GPU`).

# %%
# Install dependencies
# !pip install -q transformers datasets torchaudio gradio soundfile

# %% [markdown]
# ## Next Steps
# 1. Load the baseline model from Hugging Face.
# 2. Run inference on test sentences.
# 3. Note pronunciation issues for further tuning.
